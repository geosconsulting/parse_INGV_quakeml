# %% [markdown]
# # Note
# * conviene **tralasciare eventi sotto 2+ magnitudine** perche **riduce il traffico sul server**
# * la risposta come **testo semplifica il parsing dei dati ricevuti**
# * conviene copiare i dati in un db diviso tra **dati storici (non cambiano) e dati recenti (ultimo giorno)** che puo cambiare molto spesso
# * il **db va partizionato** cosi i dati storici sono automaticamente inseriti nelle tabelle corrette **migliorando l'efficenza delle query**

# %% [markdown]
# # Pure XML

# %%
import xml.etree.ElementTree as ET
import pandas as pd
from urllib.request import urlopen

# %%
# FROM FILE
# tree = ET.parse("working_files/response_1688110777216.xml")

# %%
# REMOTE XML
rt = 'http://webservices.ingv.it/fdsnws/event/1/query?'
st = '2023-07-05T00:00:00'
ed = '2023-07-07T23:59:59'
lat = 41.76337
lon = 12.33078
min_radius_km = 1
max_radius_km = 200

# %% [markdown]
# # Processing TEXT

# %%
url_txt = f'{rt}starttime={st}&endtime={ed}&minmag=1.0&lat={lat}&lon={lon}&minradiuskm={min_radius_km}&maxradiuskm={max_radius_km}&format=text'

# %%
url_file_opened_txt=urlopen(url_txt)
events = url_file_opened_txt.readlines()
events
# Out:
# [b'#EventID|Time|Latitude|Longitude|Depth/Km|Author|Catalog|Contributor|ContributorID|MagType|Magnitude|MagAuthor|EventLocationName|EventType\n',
#  b'35487111|2023-07-06T11:12:12.830000|42.9005|13.5837|14.0|SURVEY-INGV||||ML|1.4|--|5 km N Ascoli Piceno (AP)|earthquake\n',
#  b'35486921|2023-07-06T10:31:44.870000|42.9203|13.6118|19.2|SURVEY-INGV||||ML|1.7|--|2 km SW Castignano (AP)|earthquake\n',
#  b'35485771|2023-07-06T08:35:05.050000|42.9933|13.1477|13.2|SURVEY-INGV||||ML|1.2|--|5 km SW Acquacanina (MC)|earthquake\n',
#  b'35485671|2023-07-06T08:29:34.760000|42.8872|13.5757|14.3|SURVEY-INGV||||ML|1.2|--|4 km N Ascoli Piceno (AP)|earthquake\n',
#  b'35485591|2023-07-06T08:23:37.100000|42.9772|13.2123|5.8|SURVEY-INGV||||ML|1.3|--|2 km SW Bolognola (MC)|earthquake\n',
#  b'35485291|2023-07-06T07:41:12.930000|42.8933|13.5787|14.7|SURVEY-INGV||||ML|2.2|--|4 km N Ascoli Piceno (AP)|earthquake\n',
#  b'35484871|2023-07-06T06:42:01.460000|43.1073|13.4862|22.1|SURVEY-INGV||||ML|1.7|--|1 km E Falerone (FM)|earthquake\n',
#  b'35484261|2023-07-06T05:44:09.620000|43.432|12.4673|7.2|SURVEY-INGV||||ML|1.4|--|3 km E Pietralunga (PG)|earthquake\n',
#  b'35484081|2023-07-06T05:06:03.490000|42.6968|13.2697|10.3|SURVEY-INGV||||ML|1.0|--|2 km E Accumoli (RI)|earthquake\n',
#  b'35483971|2023-07-06T04:44:43.050000|42.9008|13.5855|14.2|SURVEY-INGV||||ML|1.2|--|5 km SW Castignano (AP)|earthquake\n',
#  b'35483621|2023-07-06T03:36:45.640000|43.0513|13.0907|7.1|SURVEY-INGV||||ML|1.1|--|1 km SE Pievebovigliana (MC)|earthquake\n',
#  b'35483401|2023-07-06T02:41:26.370000|43.4278|12.4733|7.6|SURVEY-INGV||||ML|1.4|--|3 km SE Pietralunga (PG)|earthquake\n',
#  b'35483351|2023-07-06T02:21:31.660000|41.6482|14.0555|9.5|SURVEY-INGV||||ML|1.8|--|1 km SW Castel San Vincenzo (IS)|earthquake\n',
#  b'35482741|2023-07-05T23:22:29.080000|42.5563|12.9292|13.2|SURVEY-INGV||||ML|1.6|--|3 km W Leonessa (RI)|earthquake\n',
#  b'35482611|2023-07-05T23:01:51.830000|41.9585|12.9278|9.6|SURVEY-INGV||||ML|1.6|--|1 km W Ciciliano (RM)|earthquake\n',
#  b'35482411|2023-07-05T22:40:41.770000|43.0163|12.9563|11.0|SURVEY-INGV||||ML|1.0|--|4 km NW Monte Cavallo (MC)|earthquake\n',
#  b'35482351|2023-07-05T22:39:47.290000|41.9478|12.9143|9.2|SURVEY-INGV||||ML|1.2|--|3 km SW Ciciliano (RM)|earthquake\n',
#  b'35482231|2023-07-05T21:53:31.420000|42.9827|12.9828|11.7|SURVEY-INGV||||ML|1.2|--|2 km SW Monte Cavallo (MC)|earthquake\n',
#  b'35481621|2023-07-05T19:34:49.750000|41.954|12.9158|8.9|SURVEY-INGV||||ML|1.5|--|2 km W Ciciliano (RM)|earthquake\n',
#  b'35481441|2023-07-05T18:49:11.610000|41.9468|12.9277|9.4|SURVEY-INGV||||ML|2.2|--|2 km SW Ciciliano (RM)|earthquake\n',
#  b'35481211|2023-07-05T17:55:24.370000|43.0653|13.0098|15.2|SURVEY-INGV||||ML|1.3|--|3 km SW Muccia (MC)|earthquake\n',
#  b'35480971|2023-07-05T17:39:25.600000|41.0987|10.3185|24.3|SURVEY-INGV||||ML|2.7|--|Tirreno Centrale (MARE)|earthquake\n',
#  b'35480551|2023-07-05T16:36:06.410000|42.6957|12.5722|8.5|SURVEY-INGV||||ML|1.3|--|2 km E Acquasparta (TR)|earthquake\n',
#  b'35480121|2023-07-05T15:55:56.130000|42.9813|13.2182|9.7|SURVEY-INGV||||ML|1.2|--|2 km SW Bolognola (MC)|earthquake\n',
#  b'35479771|2023-07-05T15:00:35.910000|43.3383|12.7787|12.8|SURVEY-INGV||||ML|1.0|--|3 km E Sigillo (PG)|earthquake\n',
#  b'35478911|2023-07-05T13:02:57.500000|41.9437|12.9358|8.3|SURVEY-INGV||||ML|1.4|--|2 km S Ciciliano (RM)|earthquake\n',
#  b'35478781|2023-07-05T12:39:03.790000|43.3373|13.2218|7.2|SURVEY-INGV||||ML|1.1|--|4 km S Cingoli (MC)|earthquake\n',
#  b'35478341|2023-07-05T12:08:03.830000|41.9522|12.9328|9.8|SURVEY-INGV||||ML|2.5|--|1 km SW Ciciliano (RM)|earthquake\n',
#  b'35475451|2023-07-05T07:16:02.310000|43.1147|13.0133|10.8|SURVEY-INGV||||ML|1.8|--|4 km NW Muccia (MC)|earthquake\n',
#  b'35475381|2023-07-05T07:13:15.360000|42.8453|13.0742|10.3|SURVEY-INGV||||ML|1.1|--|5 km SE Preci (PG)|earthquake\n',
#  b'35474971|2023-07-05T06:32:19.010000|43.0757|13.3287|23.4|SURVEY-INGV||||ML|1.1|--|1 km NW Gualdo (MC)|earthquake\n',
#  b'35474861|2023-07-05T06:00:10.670000|43.0673|13.0243|13.0|SURVEY-INGV||||ML|1.1|--|2 km SW Muccia (MC)|earthquake\n',
#  b'35472871|2023-07-05T02:50:37.240000|42.7308|13.0338|11.8|SURVEY-INGV||||ML|1.0|--|2 km NE Cascia (PG)|earthquake\n',
#  b'35472521|2023-07-05T00:29:00.950000|43.1323|11.0312|10.1|SURVEY-INGV||||ML|1.5|--|1 km E Montieri (GR)|earthquake\n',
#  b'35472411|2023-07-05T00:04:37.380000|42.9788|13.2162|9.0|SURVEY-INGV||||ML|1.4|--|2 km SW Bolognola (MC)|earthquake\n']

# %%
columns = events[0]
cols = [col for col in str(columns).lstrip("b'#").split("|")]
cols[-1]=cols[-1][:-3]

# %%
# cols

# %%
coded_events = []
for i in range(1,len(events)):
    event = str(events[i]).lstrip("b'").split("|")
    event[-1] = event[-1][:-3]    
    coded_events.append(event)

# %%
# coded_events

# %%
df = pd.DataFrame(coded_events, columns = cols)

# %%
df
# Out:
#      EventID                        Time Latitude Longitude Depth/Km  \
# 0   35487111  2023-07-06T11:12:12.830000  42.9005   13.5837     14.0
# 1   35486921  2023-07-06T10:31:44.870000  42.9203   13.6118     19.2
# 2   35485771  2023-07-06T08:35:05.050000  42.9933   13.1477     13.2
# 3   35485671  2023-07-06T08:29:34.760000  42.8872   13.5757     14.3
# 4   35485591  2023-07-06T08:23:37.100000  42.9772   13.2123      5.8
# 5   35485291  2023-07-06T07:41:12.930000  42.8933   13.5787     14.7
# 6   35484871  2023-07-06T06:42:01.460000  43.1073   13.4862     22.1
# 7   35484261  2023-07-06T05:44:09.620000   43.432   12.4673      7.2
# 8   35484081  2023-07-06T05:06:03.490000  42.6968   13.2697     10.3
# 9   35483971  2023-07-06T04:44:43.050000  42.9008   13.5855     14.2
# 10  35483621  2023-07-06T03:36:45.640000  43.0513   13.0907      7.1
# 11  35483401  2023-07-06T02:41:26.370000  43.4278   12.4733      7.6
# 12  35483351  2023-07-06T02:21:31.660000  41.6482   14.0555      9.5
# 13  35482741  2023-07-05T23:22:29.080000  42.5563   12.9292     13.2
# 14  35482611  2023-07-05T23:01:51.830000  41.9585   12.9278      9.6
# 15  35482411  2023-07-05T22:40:41.770000  43.0163   12.9563     11.0
# 16  35482351  2023-07-05T22:39:47.290000  41.9478   12.9143      9.2
# 17  35482231  2023-07-05T21:53:31.420000  42.9827   12.9828     11.7
# 18  35481621  2023-07-05T19:34:49.750000   41.954   12.9158      8.9
# 19  35481441  2023-07-05T18:49:11.610000  41.9468   12.9277      9.4
# 20  35481211  2023-07-05T17:55:24.370000  43.0653   13.0098     15.2
# 21  35480971  2023-07-05T17:39:25.600000  41.0987   10.3185     24.3
# 22  35480551  2023-07-05T16:36:06.410000  42.6957   12.5722      8.5
# 23  35480121  2023-07-05T15:55:56.130000  42.9813   13.2182      9.7
# 24  35479771  2023-07-05T15:00:35.910000  43.3383   12.7787     12.8
# 25  35478911  2023-07-05T13:02:57.500000  41.9437   12.9358      8.3
# 26  35478781  2023-07-05T12:39:03.790000  43.3373   13.2218      7.2
# 27  35478341  2023-07-05T12:08:03.830000  41.9522   12.9328      9.8
# 28  35475451  2023-07-05T07:16:02.310000  43.1147   13.0133     10.8
# 29  35475381  2023-07-05T07:13:15.360000  42.8453   13.0742     10.3
# 30  35474971  2023-07-05T06:32:19.010000  43.0757   13.3287     23.4
# 31  35474861  2023-07-05T06:00:10.670000  43.0673   13.0243     13.0
# 32  35472871  2023-07-05T02:50:37.240000  42.7308   13.0338     11.8
# 33  35472521  2023-07-05T00:29:00.950000  43.1323   11.0312     10.1
# 34  35472411  2023-07-05T00:04:37.380000  42.9788   13.2162      9.0
#
#          Author Catalog Contributor ContributorID MagType Magnitude MagAuthor  \
# 0   SURVEY-INGV                                        ML       1.4        --
# 1   SURVEY-INGV                                        ML       1.7        --
# 2   SURVEY-INGV                                        ML       1.2        --
# 3   SURVEY-INGV                                        ML       1.2        --
# 4   SURVEY-INGV                                        ML       1.3        --
# 5   SURVEY-INGV                                        ML       2.2        --
# 6   SURVEY-INGV                                        ML       1.7        --
# 7   SURVEY-INGV                                        ML       1.4        --
# 8   SURVEY-INGV                                        ML       1.0        --
# 9   SURVEY-INGV                                        ML       1.2        --
# 10  SURVEY-INGV                                        ML       1.1        --
# 11  SURVEY-INGV                                        ML       1.4        --
# 12  SURVEY-INGV                                        ML       1.8        --
# 13  SURVEY-INGV                                        ML       1.6        --
# 14  SURVEY-INGV                                        ML       1.6        --
# 15  SURVEY-INGV                                        ML       1.0        --
# 16  SURVEY-INGV                                        ML       1.2        --
# 17  SURVEY-INGV                                        ML       1.2        --
# 18  SURVEY-INGV                                        ML       1.5        --
# 19  SURVEY-INGV                                        ML       2.2        --
# 20  SURVEY-INGV                                        ML       1.3        --
# 21  SURVEY-INGV                                        ML       2.7        --
# 22  SURVEY-INGV                                        ML       1.3        --
# 23  SURVEY-INGV                                        ML       1.2        --
# 24  SURVEY-INGV                                        ML       1.0        --
# 25  SURVEY-INGV                                        ML       1.4        --
# 26  SURVEY-INGV                                        ML       1.1        --
# 27  SURVEY-INGV                                        ML       2.5        --
# 28  SURVEY-INGV                                        ML       1.8        --
# 29  SURVEY-INGV                                        ML       1.1        --
# 30  SURVEY-INGV                                        ML       1.1        --
# 31  SURVEY-INGV                                        ML       1.1        --
# 32  SURVEY-INGV                                        ML       1.0        --
# 33  SURVEY-INGV                                        ML       1.5        --
# 34  SURVEY-INGV                                        ML       1.4        --
#
#                    EventLocationName   EventType
# 0          5 km N Ascoli Piceno (AP)  earthquake
# 1            2 km SW Castignano (AP)  earthquake
# 2           5 km SW Acquacanina (MC)  earthquake
# 3          4 km N Ascoli Piceno (AP)  earthquake
# 4             2 km SW Bolognola (MC)  earthquake
# 5          4 km N Ascoli Piceno (AP)  earthquake
# 6               1 km E Falerone (FM)  earthquake
# 7            3 km E Pietralunga (PG)  earthquake
# 8               2 km E Accumoli (RI)  earthquake
# 9            5 km SW Castignano (AP)  earthquake
# 10      1 km SE Pievebovigliana (MC)  earthquake
# 11          3 km SE Pietralunga (PG)  earthquake
# 12  1 km SW Castel San Vincenzo (IS)  earthquake
# 13              3 km W Leonessa (RI)  earthquake
# 14             1 km W Ciciliano (RM)  earthquake
# 15        4 km NW Monte Cavallo (MC)  earthquake
# 16            3 km SW Ciciliano (RM)  earthquake
# 17        2 km SW Monte Cavallo (MC)  earthquake
# 18             2 km W Ciciliano (RM)  earthquake
# 19            2 km SW Ciciliano (RM)  earthquake
# 20               3 km SW Muccia (MC)  earthquake
# 21           Tirreno Centrale (MARE)  earthquake
# 22           2 km E Acquasparta (TR)  earthquake
# 23            2 km SW Bolognola (MC)  earthquake
# 24               3 km E Sigillo (PG)  earthquake
# 25             2 km S Ciciliano (RM)  earthquake
# 26               4 km S Cingoli (MC)  earthquake
# 27            1 km SW Ciciliano (RM)  earthquake
# 28               4 km NW Muccia (MC)  earthquake
# 29                5 km SE Preci (PG)  earthquake
# 30               1 km NW Gualdo (MC)  earthquake
# 31               2 km SW Muccia (MC)  earthquake
# 32               2 km NE Cascia (PG)  earthquake
# 33              1 km E Montieri (GR)  earthquake
# 34            2 km SW Bolognola (MC)  earthquake

# %% [markdown]
# # Processing QUAKEML

# %%
url_xml = f'{rt}starttime={st}&endtime={ed}&minmag=1.0&lat={lat}&lon={lon}&minradiuskm={min_radius_km}&maxradiuskm={max_radius_km}'
url_file_opened_xml=urlopen(url_xml)
tree = ET.parse(url_file_opened_xml)

# %%
root = tree.getroot()

# %%
root.tag
# Out:
# '{http://quakeml.org/xmlns/quakeml/1.2}quakeml'

# %%
root.attrib
# Out:
# {}

# %% [markdown]
# # ALL ATTRIBS

# %%
[elem.tag for elem in root.iter()]
# Out:
# ['{http://quakeml.org/xmlns/quakeml/1.2}quakeml',
#  '{http://quakeml.org/xmlns/bed/1.2}eventParameters',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  ...]

# %% [markdown]
# # Filtering

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# {http://quakeml.org/xmlns/bed/1.2}eventParameters {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query'}

# %%
for quake in root.iter('{http://quakeml.org/xmlns/bed/1.2}eventParameters'):
    print(quake.tag)
    print(quake.attrib)
# Out:
# {http://quakeml.org/xmlns/bed/1.2}eventParameters
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query'}

# %%
for quake in root.iter('{http://quakeml.org/xmlns/bed/1.2}event'):
    # print(quake.tag)
    print(quake.attrib)
# Out:
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35487111'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35486921'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485771'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485671'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485591'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485291'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35484871'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35484261'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35484081'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483971'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483621'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483401'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483351'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482741'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482611'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482411'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482351'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482231'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35481621'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35481441'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35481211'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35480971'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35480551'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35480121'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35479771'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35478911'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35478781'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35478341'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35475451'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35475381'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35474971'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35474861'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35472871'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35472521'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35472411'}

# %%
# for quake in root.iter('{http://quakeml.org/xmlns/bed/1.2}origin'):
#     print(quake.attrib)
# Out:
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119019041'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119017651'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119014001'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119013861'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119013831'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119012611'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119010151'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119009471'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119009031'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119008151'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119007691'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119006921'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119006091'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119002641'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119002001'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119000901'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119000871'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119000511'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118999551'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118999221'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118998321'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118998421'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118997111'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118996491'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118995861'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118992871'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118991741'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118990841'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118984021'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118984151'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118982991'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118982601'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118977411'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118975541'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118975351'}

# %%
# for quake in root.iter('{http://quakeml.org/xmlns/bed/1.2}creationTime'):
#     print(quake.text)

# %%
# for quake in root.iter('{http://quakeml.org/xmlns/bed/1.2}author'):
#     print(quake.text)

# %%
root[0].attrib
# Out:
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query'}

# %%
root[0].tag
# Out:
# '{http://quakeml.org/xmlns/bed/1.2}eventParameters'

# %%
root[0].text
# Out:
# '\n    '

# %%
root[0][0][1][1].text
# Out:
# '5 km N Ascoli Piceno (AP)'

# %% [markdown]
# # Data for Single Event

# %%
for quake in root.iter('{http://quakeml.org/xmlns/bed/1.2}event'):
    print(quake.attrib)
# Out:
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35487111'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35486921'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485771'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485671'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485591'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485291'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35484871'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35484261'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35484081'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483971'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483621'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483401'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483351'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482741'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482611'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482411'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482351'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482231'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35481621'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35481441'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35481211'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35480971'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35480551'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35480121'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35479771'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35478911'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35478781'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35478341'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35475451'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35475381'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35474971'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35474861'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35472871'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35472521'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35472411'}

# %%
event_id = 35486921

# %%
url_single_event = f'{rt}eventId={event_id}&includeallmagnitudes=true&includeallorigins=true&lat={lat}&includearrivals=true&includeallstationsmagnitudes=true'
url_single_event
# Out:
# 'http://webservices.ingv.it/fdsnws/event/1/query?eventId=35486921&includeallmagnitudes=true&includeallorigins=true&lat=41.76337&includearrivals=true&includeallstationsmagnitudes=true'

# %%
url_file_opened_xml_single_event=urlopen(url_single_event)
tree_se = ET.parse(url_file_opened_xml_single_event)
root_se = tree_se.getroot()

# %%
root_se[0][0][1][1].text
# Out:
# '2 km SW Castignano (AP)'

# %% [markdown]
# # xmltodict

# %% [markdown]
# <h1 style='color:magenta;font-family: "Times New Roman", Times, serif;font-size: 40px;'>DA IMPLEMENTARE LA LETTURA DIRETTA DA XML INGV</h1>

# %%
import xmltodict

# %%
#open the file
fileptr = open("working_files/response_1688110777216.xml","r")

# %%
#read xml content from the file
xml_content= fileptr.read()
print("XML content is:")
print(xml_content)
# Out:
# XML content is:
# <?xml version="1.0" encoding="US-ASCII" standalone="yes"?>
#   <q:quakeml xmlns:q="http://quakeml.org/xmlns/quakeml/1.2" xmlns="http://quakeml.org/xmlns/bed/1.2" xmlns:ingv="http://webservices.ingv.it/fdsnws/event/1">
#     <eventParameters publicID="smi:webservices.ingv.it/fdsnws/event/1/query">
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=33760891">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>Tirreno Meridionale (MARE)</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=121550241</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=113196041</preferredOriginID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>hew10_mole#MOD_EQASSEMBLE</author>
#           <creationTime>2022-12-29T15:11:26</creationTime>
#           <ingv:id_locator>480117</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=113196041">
#           <evaluationMode>manual</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-12-29T15:11:00.120000</value>
#             <uncertainty>0.04</uncertainty>
#           </time>
#           <latitude>
#             <value>39.3627</value>
#             <uncertainty>0.0027</uncertainty>
#           </latitude>
#           <longitude>
#             <value>15.2153</value>
#             <uncertainty>0.0047</uncertainty>
#           </longitude>
#           <depth>
#             <value>25100</value>
#             <uncertainty>500</uncertainty>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>340.0</horizontalUncertainty>
#             <minHorizontalUncertainty>250</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>344</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>289</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>80</azimuthalGap>
#             <associatedPhaseCount>221</associatedPhaseCount>
#             <usedPhaseCount>221</usedPhaseCount>
#             <standardError>0.24</standardError>
#             <minimumDistance>0.55308</minimumDistance>
#             <maximumDistance>4.03436</maximumDistance>
#             <associatedStationCount>192</associatedStationCount>
#             <usedStationCount>192</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>BULLETIN-INGV</author>
#             <version>1000</version>
#             <creationTime>2023-01-05T15:01:20</creationTime>
#             <ingv:quality>AC</ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=121550241">
#           <stationCount>344</stationCount>
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=113196041</originID>
#           <type>ML</type>
#           <mag>
#             <value>4.0</value>
#             <uncertainty>0.3</uncertainty>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>Bollettino Sismico Italiano INGV</author>
#             <creationTime>2023-01-05T15:00:13</creationTime>
#             <ingv:mag_quality>AB</ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#       </event>
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=33759321">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>Tirreno Meridionale (MARE)</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=121411131</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=113192871</preferredOriginID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>hew10_mole#MOD_EQASSEMBLE</author>
#           <creationTime>2022-12-29T12:39:18</creationTime>
#           <ingv:id_locator>480085</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=113192871">
#           <evaluationMode>manual</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-12-29T12:38:53.300000</value>
#             <uncertainty>0.05</uncertainty>
#           </time>
#           <latitude>
#             <value>39.3663</value>
#             <uncertainty>0.0027</uncertainty>
#           </latitude>
#           <longitude>
#             <value>15.2048</value>
#             <uncertainty>0.0058</uncertainty>
#           </longitude>
#           <depth>
#             <value>27700</value>
#             <uncertainty>500</uncertainty>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>340.0</horizontalUncertainty>
#             <minHorizontalUncertainty>343</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>345</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>106</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>79</azimuthalGap>
#             <associatedPhaseCount>187</associatedPhaseCount>
#             <usedPhaseCount>187</usedPhaseCount>
#             <standardError>0.29</standardError>
#             <minimumDistance>0.55668</minimumDistance>
#             <maximumDistance>4.02716</maximumDistance>
#             <associatedStationCount>167</associatedStationCount>
#             <usedStationCount>167</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>BULLETIN-INGV</author>
#             <version>1000</version>
#             <creationTime>2023-01-05T15:01:20</creationTime>
#             <ingv:quality>AC</ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=121411131">
#           <stationCount>324</stationCount>
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=113192871</originID>
#           <type>ML</type>
#           <mag>
#             <value>4.0</value>
#             <uncertainty>0.3</uncertainty>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>Bollettino Sismico Italiano INGV</author>
#             <creationTime>2022-12-30T14:54:38</creationTime>
#             <ingv:mag_quality>AB</ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#       </event>
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=33554561">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>Isole Eolie (Messina)</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=127024981</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=112487121</preferredOriginID>
#         <preferredFocalMechanismID>smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=19951</preferredFocalMechanismID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>hew10_mole#MOD_EQASSEMBLE</author>
#           <creationTime>2022-12-04T07:13:06</creationTime>
#           <ingv:id_locator>476139</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=112487121">
#           <evaluationMode>manual</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-12-04T07:12:45.370000</value>
#           </time>
#           <latitude>
#             <value>38.354</value>
#           </latitude>
#           <longitude>
#             <value>14.859</value>
#           </longitude>
#           <depth>
#             <value>3060</value>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>horizontal uncertainty</preferredDescription>
#             <horizontalUncertainty>400.0</horizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>100</azimuthalGap>
#             <associatedPhaseCount>1</associatedPhaseCount>
#             <usedPhaseCount>1</usedPhaseCount>
#             <standardError>0.27</standardError>
#             <associatedStationCount>0</associatedStationCount>
#             <usedStationCount>0</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=301</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=51</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>SURVEY-INGV-CT</author>
#             <version>200</version>
#             <creationTime>2022-12-04T07:47:44</creationTime>
#             <ingv:quality>CB</ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=127024981">
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=118205291</originID>
#           <type>Mw</type>
#           <mag>
#             <value>4.5</value>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=351</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>TDMT-INGV Revised</author>
#             <creationTime>2023-06-08T08:47:32</creationTime>
#             <ingv:mag_quality>
#             </ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#         <focalMechanism publicID="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=19951">
#           <triggeringOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=112487121</triggeringOriginID>
#           <nodalPlanes>
#             <nodalPlane1>
#               <strike>
#                 <value>128</value>
#               </strike>
#               <dip>
#                 <value>80</value>
#               </dip>
#               <rake>
#                 <value>158</value>
#               </rake>
#             </nodalPlane1>
#             <nodalPlane2>
#               <strike>
#                 <value>221</value>
#               </strike>
#               <dip>
#                 <value>69</value>
#               </dip>
#               <rake>
#                 <value>10</value>
#               </rake>
#             </nodalPlane2>
#           </nodalPlanes>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>Laura Scognamiglio (laura.scognamiglio@ingv.it) and Elisa Tinti (elisa.tinti@ingv.it) | Reference: http://terremoti.ingv.it/help#TDMT</author>
#             <creationTime>2023-06-08T08:47:32</creationTime>
#           </creationInfo>
#           <evaluationMode>manual</evaluationMode>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <momentTensor publicID="smi:webservices.ingv.it/fdsnws/event/1/query?momentTensorId=19951">
#             <varianceReduction>41.06</varianceReduction>
#             <doubleCouple>0.9100</doubleCouple>
#             <clvd>0.0900</clvd>
#             <iso>0.0000</iso>
#             <derivedOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=118205291</derivedOriginID>
#             <momentMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=127024981</momentMagnitudeID>
#             <tensor>
#               <Mrr>
#                 <value>562110000000000</value>
#               </Mrr>
#               <Mtt>
#                 <value>-6.10581e15</value>
#               </Mtt>
#               <Mpp>
#                 <value>5.54371e15</value>
#               </Mpp>
#               <Mrt>
#                 <value>1.11868e15</value>
#               </Mrt>
#               <Mrp>
#                 <value>-2.34212e15</value>
#               </Mrp>
#               <Mtp>
#                 <value>-1.14615e15</value>
#               </Mtp>
#             </tensor>
#             <scalarMoment>
#               <value>6.49201e15</value>
#             </scalarMoment>
#             <dataUsed>
#               <waveType>combined</waveType>
#             </dataUsed>
#             <creationInfo>
#               <agencyID>INGV</agencyID>
#               <author>Laura Scognamiglio (laura.scognamiglio@ingv.it) and Elisa Tinti (elisa.tinti@ingv.it) | Reference: http://terremoti.ingv.it/help#TDMT</author>
#               <creationTime>2023-06-08T08:47:32</creationTime>
#             </creationInfo>
#           </momentTensor>
#         </focalMechanism>
#       </event>
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=33545491">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>Bosnia and Herz. [Land]</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=120599821</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=112447031</preferredOriginID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>hew10_mole#MOD_EQASSEMBLE</author>
#           <creationTime>2022-12-02T20:05:56</creationTime>
#           <ingv:id_locator>475956</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=112447031">
#           <evaluationMode>manual</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-12-02T20:05:06.870000</value>
#             <uncertainty>0.34</uncertainty>
#           </time>
#           <latitude>
#             <value>43.0918</value>
#             <uncertainty>0.0261</uncertainty>
#           </latitude>
#           <longitude>
#             <value>18.1082</value>
#             <uncertainty>0.0222</uncertainty>
#           </longitude>
#           <depth>
#             <value>17600</value>
#             <uncertainty>2800</uncertainty>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>2410.0</horizontalUncertainty>
#             <minHorizontalUncertainty>1999</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>2405</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>198</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>201</azimuthalGap>
#             <associatedPhaseCount>188</associatedPhaseCount>
#             <usedPhaseCount>20</usedPhaseCount>
#             <standardError>0.44</standardError>
#             <minimumDistance>0.00000</minimumDistance>
#             <maximumDistance>2.96506</maximumDistance>
#             <associatedStationCount>173</associatedStationCount>
#             <usedStationCount>15</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>SURVEY-INGV</author>
#             <version>100</version>
#             <creationTime>2022-12-02T20:35:00</creationTime>
#             <ingv:quality>BD</ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=120599821">
#           <stationCount>394</stationCount>
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=112447031</originID>
#           <type>ML</type>
#           <mag>
#             <value>4.5</value>
#             <uncertainty>0.3</uncertainty>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>Sala Sismica INGV-Roma</author>
#             <creationTime>2022-12-02T20:34:59</creationTime>
#             <ingv:mag_quality>AB</ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#       </event>
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=33508291">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>Bosnia and Herz. [Land]</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=120423541</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=112289151</preferredOriginID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>early-est_ee1.1.9#ee</author>
#           <creationTime>2022-11-28T07:53:12</creationTime>
#           <ingv:id_locator>1669621790817</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=112289151">
#           <evaluationMode>automatic</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-11-28T07:49:50.077000</value>
#           </time>
#           <latitude>
#             <value>44.456</value>
#           </latitude>
#           <longitude>
#             <value>17.8333</value>
#           </longitude>
#           <depth>
#             <value>10059</value>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>1849.0</horizontalUncertainty>
#             <minHorizontalUncertainty>1804</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>2291</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>235</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>52.3378</azimuthalGap>
#             <associatedPhaseCount>19</associatedPhaseCount>
#             <usedPhaseCount>19</usedPhaseCount>
#             <standardError>1.03841</standardError>
#             <minimumDistance>0.54725</minimumDistance>
#             <maximumDistance>7.60567</maximumDistance>
#             <associatedStationCount>19</associatedStationCount>
#             <usedStationCount>19</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=141</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>SURVEY-INGV-A</author>
#             <version>100</version>
#             <creationTime>2022-11-28T08:10:26</creationTime>
#             <ingv:quality>
#             </ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=120423541">
#           <stationCount>7</stationCount>
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=112289151</originID>
#           <type>mb</type>
#           <mag>
#             <value>4.3</value>
#             <uncertainty>0.1</uncertainty>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=141</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>early-est_ee1.1.9</author>
#             <creationTime>2022-11-28T08:10:26</creationTime>
#             <ingv:mag_quality>
#             </ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#       </event>
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=33456501">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>Malta (MALTA)</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=120332511</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=112135281</preferredOriginID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>hew10_mole#MOD_EQASSEMBLE</author>
#           <creationTime>2022-11-22T12:41:05</creationTime>
#           <ingv:id_locator>474315</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=112135281">
#           <evaluationMode>manual</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-11-22T12:40:33.230000</value>
#             <uncertainty>0.16</uncertainty>
#           </time>
#           <latitude>
#             <value>36.034</value>
#             <uncertainty>0.0099</uncertainty>
#           </latitude>
#           <longitude>
#             <value>14.1937</value>
#             <uncertainty>0.0122</uncertainty>
#           </longitude>
#           <depth>
#             <value>17400</value>
#             <uncertainty>1000</uncertainty>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>1380.0</horizontalUncertainty>
#             <minHorizontalUncertainty>234</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>1385</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>315</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>185</azimuthalGap>
#             <associatedPhaseCount>82</associatedPhaseCount>
#             <usedPhaseCount>82</usedPhaseCount>
#             <standardError>0.31</standardError>
#             <minimumDistance>0.84356</minimumDistance>
#             <maximumDistance>7.11184</maximumDistance>
#             <associatedStationCount>62</associatedStationCount>
#             <usedStationCount>62</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>BULLETIN-INGV</author>
#             <version>1000</version>
#             <creationTime>2022-11-25T16:10:59</creationTime>
#             <ingv:quality>AD</ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=120332511">
#           <stationCount>120</stationCount>
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=112135281</originID>
#           <type>ML</type>
#           <mag>
#             <value>4.3</value>
#             <uncertainty>0.3</uncertainty>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>Bollettino Sismico Italiano INGV</author>
#             <creationTime>2022-11-25T16:09:20</creationTime>
#             <ingv:mag_quality>AC</ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#       </event>
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=33431491">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>Costa Marchigiana Pesarese (Pesaro-Urbino)</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=120294531</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=112015961</preferredOriginID>
#         <preferredFocalMechanismID>smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=19851</preferredFocalMechanismID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>hew10_mole#MOD_EQASSEMBLE</author>
#           <creationTime>2022-11-20T05:20:49</creationTime>
#           <ingv:id_locator>473947</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=112015961">
#           <evaluationMode>manual</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-11-20T05:20:30.250000</value>
#             <uncertainty>0.3</uncertainty>
#           </time>
#           <latitude>
#             <value>43.9027</value>
#             <uncertainty>0.0135</uncertainty>
#           </latitude>
#           <longitude>
#             <value>13.2642</value>
#             <uncertainty>0.0125</uncertainty>
#           </longitude>
#           <depth>
#             <value>10300</value>
#             <uncertainty>900</uncertainty>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>1630.0</horizontalUncertainty>
#             <minHorizontalUncertainty>290</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>1626</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>210</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>207</azimuthalGap>
#             <associatedPhaseCount>229</associatedPhaseCount>
#             <usedPhaseCount>52</usedPhaseCount>
#             <standardError>0.42</standardError>
#             <minimumDistance>0.00000</minimumDistance>
#             <maximumDistance>1.14933</maximumDistance>
#             <associatedStationCount>203</associatedStationCount>
#             <usedStationCount>42</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>SURVEY-INGV</author>
#             <version>100</version>
#             <creationTime>2022-11-20T05:39:50</creationTime>
#             <ingv:quality>AD</ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=120294531">
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=112171571</originID>
#           <type>Mw</type>
#           <mag>
#             <value>4.2</value>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=161</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>TDMT-INGV Revised</author>
#             <creationTime>2022-11-24T18:05:34</creationTime>
#             <ingv:mag_quality>
#             </ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#         <focalMechanism publicID="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=19851">
#           <triggeringOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=112015961</triggeringOriginID>
#           <nodalPlanes>
#             <nodalPlane1>
#               <strike>
#                 <value>140</value>
#               </strike>
#               <dip>
#                 <value>53</value>
#               </dip>
#               <rake>
#                 <value>87</value>
#               </rake>
#             </nodalPlane1>
#             <nodalPlane2>
#               <strike>
#                 <value>325</value>
#               </strike>
#               <dip>
#                 <value>37</value>
#               </dip>
#               <rake>
#                 <value>94</value>
#               </rake>
#             </nodalPlane2>
#           </nodalPlanes>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>Laura Scognamiglio (laura.scognamiglio@ingv.it) and Elisa Tinti (elisa.tinti@ingv.it) | Reference: http://terremoti.ingv.it/help#TDMT</author>
#             <creationTime>2022-11-24T18:05:34</creationTime>
#           </creationInfo>
#           <evaluationMode>manual</evaluationMode>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <momentTensor publicID="smi:webservices.ingv.it/fdsnws/event/1/query?momentTensorId=19851">
#             <varianceReduction>45.57</varianceReduction>
#             <doubleCouple>0.8800</doubleCouple>
#             <clvd>0.1200</clvd>
#             <iso>0.0000</iso>
#             <derivedOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=112171571</derivedOriginID>
#             <momentMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=120294531</momentMagnitudeID>
#             <tensor>
#               <Mrr>
#                 <value>2.29284e15</value>
#               </Mrr>
#               <Mtt>
#                 <value>-815740000000000</value>
#               </Mtt>
#               <Mpp>
#                 <value>-1.4771e15</value>
#               </Mpp>
#               <Mrt>
#                 <value>507760000000000.06</value>
#               </Mrt>
#               <Mrp>
#                 <value>-481560000000000</value>
#               </Mrp>
#               <Mtp>
#                 <value>1.26029e15</value>
#               </Mtp>
#             </tensor>
#             <scalarMoment>
#               <value>2.47245e15</value>
#             </scalarMoment>
#             <dataUsed>
#               <waveType>combined</waveType>
#               <stationCount>24</stationCount>
#               <componentCount>72</componentCount>
#             </dataUsed>
#             <creationInfo>
#               <agencyID>INGV</agencyID>
#               <author>Laura Scognamiglio (laura.scognamiglio@ingv.it) and Elisa Tinti (elisa.tinti@ingv.it) | Reference: http://terremoti.ingv.it/help#TDMT</author>
#               <creationTime>2022-11-24T18:05:34</creationTime>
#             </creationInfo>
#           </momentTensor>
#         </focalMechanism>
#       </event>
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=33332891">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>Costa Marchigiana Anconetana (Ancona)</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=119822411</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=111727551</preferredOriginID>
#         <preferredFocalMechanismID>smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=19711</preferredFocalMechanismID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>hew20_mole#MOD_EQASSEMBLE</author>
#           <creationTime>2022-11-10T17:54:34</creationTime>
#           <ingv:id_locator>508334</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=111727551">
#           <evaluationMode>manual</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-11-10T17:54:12.160000</value>
#             <uncertainty>0.11</uncertainty>
#           </time>
#           <latitude>
#             <value>43.9155</value>
#             <uncertainty>0.0045</uncertainty>
#           </latitude>
#           <longitude>
#             <value>13.3372</value>
#             <uncertainty>0.0050</uncertainty>
#           </longitude>
#           <depth>
#             <value>6400</value>
#             <uncertainty>400</uncertainty>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>600.0</horizontalUncertainty>
#             <minHorizontalUncertainty>121</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>599</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>211</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>64</azimuthalGap>
#             <associatedPhaseCount>296</associatedPhaseCount>
#             <usedPhaseCount>296</usedPhaseCount>
#             <standardError>0.3</standardError>
#             <minimumDistance>0.22303</minimumDistance>
#             <maximumDistance>4.35542</maximumDistance>
#             <associatedStationCount>257</associatedStationCount>
#             <usedStationCount>257</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>BULLETIN-INGV</author>
#             <version>1000</version>
#             <creationTime>2022-11-13T12:20:18</creationTime>
#             <ingv:quality>AC</ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=119822411">
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=111727001</originID>
#           <type>Mw</type>
#           <mag>
#             <value>4.0</value>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=161</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>TDMT-INGV Revised</author>
#             <creationTime>2022-11-11T16:02:45</creationTime>
#             <ingv:mag_quality>
#             </ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#         <focalMechanism publicID="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=19711">
#           <triggeringOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=111690161</triggeringOriginID>
#           <nodalPlanes>
#             <nodalPlane1>
#               <strike>
#                 <value>319</value>
#               </strike>
#               <dip>
#                 <value>52</value>
#               </dip>
#               <rake>
#                 <value>89</value>
#               </rake>
#             </nodalPlane1>
#             <nodalPlane2>
#               <strike>
#                 <value>140</value>
#               </strike>
#               <dip>
#                 <value>38</value>
#               </dip>
#               <rake>
#                 <value>91</value>
#               </rake>
#             </nodalPlane2>
#           </nodalPlanes>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>Laura Scognamiglio (laura.scognamiglio@ingv.it) and Elisa Tinti (elisa.tinti@ingv.it) | Reference: http://terremoti.ingv.it/help#TDMT</author>
#             <creationTime>2022-11-11T16:02:45</creationTime>
#           </creationInfo>
#           <evaluationMode>manual</evaluationMode>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <momentTensor publicID="smi:webservices.ingv.it/fdsnws/event/1/query?momentTensorId=19711">
#             <varianceReduction>46.22</varianceReduction>
#             <doubleCouple>0.9100</doubleCouple>
#             <clvd>0.0900</clvd>
#             <iso>0.0000</iso>
#             <derivedOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=111727001</derivedOriginID>
#             <momentMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=119822411</momentMagnitudeID>
#             <tensor>
#               <Mrr>
#                 <value>1099180000000000.1</value>
#               </Mrr>
#               <Mtt>
#                 <value>-452380000000000</value>
#               </Mtt>
#               <Mpp>
#                 <value>-646800000000000.1</value>
#               </Mpp>
#               <Mrt>
#                 <value>-204780000000000</value>
#               </Mrt>
#               <Mrp>
#                 <value>221439999999999.97</value>
#               </Mrp>
#               <Mtp>
#                 <value>597620000000000</value>
#               </Mtp>
#             </tensor>
#             <scalarMoment>
#               <value>1.16679e15</value>
#             </scalarMoment>
#             <dataUsed>
#               <waveType>combined</waveType>
#               <stationCount>22</stationCount>
#               <componentCount>66</componentCount>
#             </dataUsed>
#             <creationInfo>
#               <agencyID>INGV</agencyID>
#               <author>Laura Scognamiglio (laura.scognamiglio@ingv.it) and Elisa Tinti (elisa.tinti@ingv.it) | Reference: http://terremoti.ingv.it/help#TDMT</author>
#               <creationTime>2022-11-11T16:02:45</creationTime>
#             </creationInfo>
#           </momentTensor>
#         </focalMechanism>
#       </event>
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=33302041">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>Costa Marchigiana Pesarese (Pesaro-Urbino)</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=119821081</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=111657661</preferredOriginID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>hew10_mole#MOD_EQASSEMBLE</author>
#           <creationTime>2022-11-09T06:13:19</creationTime>
#           <ingv:id_locator>471501</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=111657661">
#           <evaluationMode>manual</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-11-09T06:12:57.730000</value>
#             <uncertainty>0.16</uncertainty>
#           </time>
#           <latitude>
#             <value>43.9662</value>
#             <uncertainty>0.0072</uncertainty>
#           </latitude>
#           <longitude>
#             <value>13.3015</value>
#             <uncertainty>0.0062</uncertainty>
#           </longitude>
#           <depth>
#             <value>4700</value>
#             <uncertainty>600</uncertainty>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>830.0</horizontalUncertainty>
#             <minHorizontalUncertainty>133</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>825</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>200</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>124</azimuthalGap>
#             <associatedPhaseCount>210</associatedPhaseCount>
#             <usedPhaseCount>210</usedPhaseCount>
#             <standardError>0.29</standardError>
#             <minimumDistance>0.23832</minimumDistance>
#             <maximumDistance>4.10450</maximumDistance>
#             <associatedStationCount>181</associatedStationCount>
#             <usedStationCount>181</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>BULLETIN-INGV</author>
#             <version>1000</version>
#             <creationTime>2022-11-14T15:27:30</creationTime>
#             <ingv:quality>AC</ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=119821081">
#           <stationCount>155</stationCount>
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=111657661</originID>
#           <type>ML</type>
#           <mag>
#             <value>4.0</value>
#             <uncertainty>0.3</uncertainty>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>Bollettino Sismico Italiano INGV</author>
#             <creationTime>2022-11-11T15:11:31</creationTime>
#             <ingv:mag_quality>AB</ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#       </event>
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=33301931">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>Costa Marchigiana Anconetana (Ancona)</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=119720801</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=111623571</preferredOriginID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>hew3_mole#MOD_EQASSEMBLE</author>
#           <creationTime>2022-11-09T06:08:49</creationTime>
#           <ingv:id_locator>654665</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=111623571">
#           <evaluationMode>manual</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-11-09T06:08:28.990000</value>
#             <uncertainty>0.2</uncertainty>
#           </time>
#           <latitude>
#             <value>43.9133</value>
#             <uncertainty>0.0090</uncertainty>
#           </latitude>
#           <longitude>
#             <value>13.3447</value>
#             <uncertainty>0.0087</uncertainty>
#           </longitude>
#           <depth>
#             <value>7700</value>
#             <uncertainty>700</uncertainty>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>1080.0</horizontalUncertainty>
#             <minHorizontalUncertainty>52</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>1079</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>205</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>221</azimuthalGap>
#             <associatedPhaseCount>135</associatedPhaseCount>
#             <usedPhaseCount>135</usedPhaseCount>
#             <standardError>0.29</standardError>
#             <minimumDistance>0.00000</minimumDistance>
#             <maximumDistance>1.73389</maximumDistance>
#             <associatedStationCount>112</associatedStationCount>
#             <usedStationCount>112</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>BULLETIN-INGV</author>
#             <version>1000</version>
#             <creationTime>2022-11-09T10:30:37</creationTime>
#             <ingv:quality>AD</ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=119720801">
#           <stationCount>118</stationCount>
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=111623571</originID>
#           <type>ML</type>
#           <mag>
#             <value>5.2</value>
#             <uncertainty>0.2</uncertainty>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>Bollettino Sismico Italiano INGV</author>
#             <creationTime>2022-11-09T09:41:32</creationTime>
#             <ingv:mag_quality>BB</ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#       </event>
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=33301831">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>Costa Marchigiana Pesarese (Pesaro-Urbino)</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=119712701</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=111637921</preferredOriginID>
#         <preferredFocalMechanismID>smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=19591</preferredFocalMechanismID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>hew10_mole#MOD_EQASSEMBLE</author>
#           <creationTime>2022-11-09T06:07:46</creationTime>
#           <ingv:id_locator>471498</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=111637921">
#           <evaluationMode>manual</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-11-09T06:07:25.000000</value>
#             <uncertainty>0.12</uncertainty>
#           </time>
#           <latitude>
#             <value>43.9833</value>
#             <uncertainty>0.0054</uncertainty>
#           </latitude>
#           <longitude>
#             <value>13.3237</value>
#             <uncertainty>0.0062</uncertainty>
#           </longitude>
#           <depth>
#             <value>5000</value>
#             <uncertainty>600</uncertainty>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>630.0</horizontalUncertainty>
#             <minHorizontalUncertainty>224</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>634</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>28</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>64</azimuthalGap>
#             <associatedPhaseCount>263</associatedPhaseCount>
#             <usedPhaseCount>250</usedPhaseCount>
#             <standardError>0.28</standardError>
#             <minimumDistance>0.26080</minimumDistance>
#             <maximumDistance>3.01902</maximumDistance>
#             <associatedStationCount>228</associatedStationCount>
#             <usedStationCount>215</usedStationCount>
#           </quality>
# ...
#             <uncertainty>0.08</uncertainty>
#           </time>
#           <latitude>
#             <value>44.7862</value>
#             <uncertainty>0.0027</uncertainty>
#           </latitude>
#           <longitude>
#             <value>10.7237</value>
#             <uncertainty>0.0051</uncertainty>
#           </longitude>
#           <depth>
#             <value>7000</value>
#             <uncertainty>600</uncertainty>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>340.0</horizontalUncertainty>
#             <minHorizontalUncertainty>282</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>342</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>289</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>18</azimuthalGap>
#             <associatedPhaseCount>249</associatedPhaseCount>
#             <usedPhaseCount>249</usedPhaseCount>
#             <standardError>0.28</standardError>
#             <minimumDistance>0.16008</minimumDistance>
#             <maximumDistance>3.60898</maximumDistance>
#             <associatedStationCount>221</associatedStationCount>
#             <usedStationCount>221</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>BULLETIN-INGV</author>
#             <version>1000</version>
#             <creationTime>2022-07-08T12:33:27</creationTime>
#             <ingv:quality>AB</ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=127025031">
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=118205371</originID>
#           <type>Mw</type>
#           <mag>
#             <value>4.3</value>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=171</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>TDMT-INGV Revised</author>
#             <creationTime>2023-06-08T08:51:19</creationTime>
#             <ingv:mag_quality>
#             </ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#         <focalMechanism publicID="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=18391">
#           <triggeringOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=100817861</triggeringOriginID>
#           <nodalPlanes>
#             <nodalPlane1>
#               <strike>
#                 <value>208</value>
#               </strike>
#               <dip>
#                 <value>90</value>
#               </dip>
#               <rake>
#                 <value>49</value>
#               </rake>
#             </nodalPlane1>
#             <nodalPlane2>
#               <strike>
#                 <value>118</value>
#               </strike>
#               <dip>
#                 <value>41</value>
#               </dip>
#               <rake>
#                 <value>180</value>
#               </rake>
#             </nodalPlane2>
#           </nodalPlanes>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>Laura Scognamiglio (laura.scognamiglio@ingv.it) and Elisa Tinti (elisa.tinti@ingv.it) | Reference: http://terremoti.ingv.it/help#TDMT</author>
#             <creationTime>2023-06-08T08:51:19</creationTime>
#           </creationInfo>
#           <evaluationMode>manual</evaluationMode>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <momentTensor publicID="smi:webservices.ingv.it/fdsnws/event/1/query?momentTensorId=18391">
#             <varianceReduction>29.55</varianceReduction>
#             <doubleCouple>0.9700</doubleCouple>
#             <clvd>0.0300</clvd>
#             <iso>0.0000</iso>
#             <derivedOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=118205371</derivedOriginID>
#             <momentMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=127025031</momentMagnitudeID>
#             <tensor>
#               <Mrr>
#                 <value>9360000000000</value>
#               </Mrr>
#               <Mtt>
#                 <value>-1.90412e15</value>
#               </Mtt>
#               <Mpp>
#                 <value>1.89476e15</value>
#               </Mpp>
#               <Mrt>
#                 <value>-1.26482e15</value>
#               </Mrt>
#               <Mrp>
#                 <value>-2.26793e15</value>
#               </Mrp>
#               <Mtp>
#                 <value>-1285389999999999.8</value>
#               </Mtp>
#             </tensor>
#             <scalarMoment>
#               <value>3.46427e15</value>
#             </scalarMoment>
#             <dataUsed>
#               <waveType>combined</waveType>
#             </dataUsed>
#             <creationInfo>
#               <agencyID>INGV</agencyID>
#               <author>Laura Scognamiglio (laura.scognamiglio@ingv.it) and Elisa Tinti (elisa.tinti@ingv.it) | Reference: http://terremoti.ingv.it/help#TDMT</author>
#               <creationTime>2023-06-08T08:51:19</creationTime>
#             </creationInfo>
#           </momentTensor>
#         </focalMechanism>
#       </event>
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=29882731">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>5 km E Bagnolo in Piano (RE)</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=108217871</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=100841481</preferredOriginID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>hew10_mole#MOD_EQASSEMBLE</author>
#           <creationTime>2022-02-09T18:55:31</creationTime>
#           <ingv:id_locator>407625</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=100841481">
#           <evaluationMode>manual</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-02-09T18:55:12.780000</value>
#             <uncertainty>0.07</uncertainty>
#           </time>
#           <latitude>
#             <value>44.7803</value>
#             <uncertainty>0.0018</uncertainty>
#           </latitude>
#           <longitude>
#             <value>10.7252</value>
#             <uncertainty>0.0051</uncertainty>
#           </longitude>
#           <depth>
#             <value>6100</value>
#             <uncertainty>400</uncertainty>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>270.0</horizontalUncertainty>
#             <minHorizontalUncertainty>249</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>271</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>281</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>18</azimuthalGap>
#             <associatedPhaseCount>248</associatedPhaseCount>
#             <usedPhaseCount>248</usedPhaseCount>
#             <standardError>0.26</standardError>
#             <minimumDistance>0.16278</minimumDistance>
#             <maximumDistance>6.12528</maximumDistance>
#             <associatedStationCount>210</associatedStationCount>
#             <usedStationCount>210</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>BULLETIN-INGV</author>
#             <version>1000</version>
#             <creationTime>2022-07-08T12:33:27</creationTime>
#             <ingv:quality>AB</ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=108217871">
#           <stationCount>450</stationCount>
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=100841481</originID>
#           <type>ML</type>
#           <mag>
#             <value>4.0</value>
#             <uncertainty>0.3</uncertainty>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>Bollettino Sismico Italiano INGV</author>
#             <creationTime>2022-02-14T15:46:24</creationTime>
#             <ingv:mag_quality>AC</ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#       </event>
#       <event publicID="smi:webservices.ingv.it/fdsnws/event/1/query?eventId=29600121">
#         <type>earthquake</type>
#         <description>
#           <type>region name</type>
#           <text>Costa Calabra sud-occidentale (Catanzaro, Vibo Valentia, Reggio di Calabria)</text>
#         </description>
#         <preferredMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=107142941</preferredMagnitudeID>
#         <preferredOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=100005731</preferredOriginID>
#         <preferredFocalMechanismID>smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=18331</preferredFocalMechanismID>
#         <creationInfo>
#           <agencyID>INGV</agencyID>
#           <author>hew10_mole#MOD_EQASSEMBLE</author>
#           <creationTime>2022-01-20T09:20:18</creationTime>
#           <ingv:id_locator>399404</ingv:id_locator>
#         </creationInfo>
#         <origin publicID="smi:webservices.ingv.it/fdsnws/event/1/query?originId=100005731">
#           <evaluationMode>manual</evaluationMode>
#           <type>hypocenter</type>
#           <time>
#             <value>2022-01-20T09:19:57.010000</value>
#             <uncertainty>0.14</uncertainty>
#           </time>
#           <latitude>
#             <value>38.8307</value>
#             <uncertainty>0.0045</uncertainty>
#           </latitude>
#           <longitude>
#             <value>16.0423</value>
#             <uncertainty>0.0069</uncertainty>
#           </longitude>
#           <depth>
#             <value>7000</value>
#             <uncertainty>1000</uncertainty>
#           </depth>
#           <depthType>from location</depthType>
#           <originUncertainty>
#             <preferredDescription>uncertainty ellipse</preferredDescription>
#             <horizontalUncertainty>630.0</horizontalUncertainty>
#             <minHorizontalUncertainty>270</minHorizontalUncertainty>
#             <maxHorizontalUncertainty>634</maxHorizontalUncertainty>
#             <azimuthMaxHorizontalUncertainty>297</azimuthMaxHorizontalUncertainty>
#             <confidenceLevel>68</confidenceLevel>
#           </originUncertainty>
#           <quality>
#             <azimuthalGap>49</azimuthalGap>
#             <associatedPhaseCount>144</associatedPhaseCount>
#             <usedPhaseCount>144</usedPhaseCount>
#             <standardError>0.42</standardError>
#             <minimumDistance>0.19695</minimumDistance>
#             <maximumDistance>5.64055</maximumDistance>
#             <associatedStationCount>126</associatedStationCount>
#             <usedStationCount>126</usedStationCount>
#           </quality>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=1</methodID>
#           <earthModelID>smi:webservices.ingv.it/fdsnws/event/1/query?earthModelId=1</earthModelID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>BULLETIN-INGV</author>
#             <version>1000</version>
#             <creationTime>2022-01-26T17:34:52</creationTime>
#             <ingv:quality>AC</ingv:quality>
#           </creationInfo>
#         </origin>
#         <magnitude publicID="smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=107142941">
#           <originID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=99973131</originID>
#           <type>Mw</type>
#           <mag>
#             <value>4.3</value>
#           </mag>
#           <methodID>smi:webservices.ingv.it/fdsnws/event/1/query?methodId=161</methodID>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>TDMT-INGV Revised</author>
#             <creationTime>2022-01-20T10:18:16</creationTime>
#             <ingv:mag_quality>
#             </ingv:mag_quality>
#           </creationInfo>
#         </magnitude>
#         <focalMechanism publicID="smi:webservices.ingv.it/fdsnws/event/1/query?focalMechanismId=18331">
#           <triggeringOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=99971421</triggeringOriginID>
#           <nodalPlanes>
#             <nodalPlane1>
#               <strike>
#                 <value>213</value>
#               </strike>
#               <dip>
#                 <value>63</value>
#               </dip>
#               <rake>
#                 <value>-116</value>
#               </rake>
#             </nodalPlane1>
#             <nodalPlane2>
#               <strike>
#                 <value>80</value>
#               </strike>
#               <dip>
#                 <value>36</value>
#               </dip>
#               <rake>
#                 <value>-49</value>
#               </rake>
#             </nodalPlane2>
#           </nodalPlanes>
#           <creationInfo>
#             <agencyID>INGV</agencyID>
#             <author>Laura Scognamiglio (laura.scognamiglio@ingv.it) and Elisa Tinti (elisa.tinti@ingv.it) | Reference: http://terremoti.ingv.it/help#TDMT</author>
#             <creationTime>2022-01-20T10:18:16</creationTime>
#           </creationInfo>
#           <evaluationMode>manual</evaluationMode>
#           <evaluationStatus>reviewed</evaluationStatus>
#           <momentTensor publicID="smi:webservices.ingv.it/fdsnws/event/1/query?momentTensorId=18331">
#             <varianceReduction>42.02</varianceReduction>
#             <doubleCouple>0.9600</doubleCouple>
#             <clvd>0.0400</clvd>
#             <iso>0.0000</iso>
#             <derivedOriginID>smi:webservices.ingv.it/fdsnws/event/1/query?originId=99973131</derivedOriginID>
#             <momentMagnitudeID>smi:webservices.ingv.it/fdsnws/event/1/query?magnitudeId=107142941</momentMagnitudeID>
#             <tensor>
#               <Mrr>
#                 <value>-2.26782e15</value>
#               </Mrr>
#               <Mtt>
#                 <value>1807769999999999.8</value>
#               </Mtt>
#               <Mpp>
#                 <value>460050000000000</value>
#               </Mpp>
#               <Mrt>
#                 <value>453340000000000.06</value>
#               </Mrt>
#               <Mrp>
#                 <value>1.74341e15</value>
#               </Mrp>
#               <Mtp>
#                 <value>1.5707e15</value>
#               </Mtp>
#             </tensor>
#             <scalarMoment>
#               <value>3.16556e15</value>
#             </scalarMoment>
#             <dataUsed>
#               <waveType>combined</waveType>
#               <stationCount>13</stationCount>
#               <componentCount>39</componentCount>
#             </dataUsed>
#             <creationInfo>
#               <agencyID>INGV</agencyID>
#               <author>Laura Scognamiglio (laura.scognamiglio@ingv.it) and Elisa Tinti (elisa.tinti@ingv.it) | Reference: http://terremoti.ingv.it/help#TDMT</author>
#               <creationTime>2022-01-20T10:18:16</creationTime>
#             </creationInfo>
#           </momentTensor>
#         </focalMechanism>
#       </event>
#     </eventParameters>
#   </q:quakeml>

# %%
#change xml format to ordered dict
my_ordered_dict=xmltodict.parse(xml_content)
print("Ordered Dictionary is:")
# print(my_ordered_dict)
# Out:
# Ordered Dictionary is:

# %%
# print(my_ordered_dict['q:quakeml']['eventParameters']['event'])

# %%
events = my_ordered_dict['q:quakeml']['eventParameters']['event']

# %%
my_ordered_dict['q:quakeml']['eventParameters']['event'][0].keys()
# Out:
# dict_keys(['@publicID', 'type', 'description', 'preferredMagnitudeID', 'preferredOriginID', 'creationInfo', 'origin', 'magnitude'])

# %%
for i in range(2):
    print(events[i]['@publicID'].split('?')[1].split('=')[1])
# Out:
# 33760891
# 33759321

# %%
# for event in events:
#     print(event['description'])

# %%
print("Location is:")
print(my_ordered_dict['q:quakeml']['eventParameters']['event'][0]['description'])
# Out:
# Location is:
# {'type': 'region name', 'text': 'Tirreno Meridionale (MARE)'}

# %%
dati_scelti = []
for event in events:
    dati_scelti.append([event['@publicID'].split('?')[1].split('=')[1],
                        event['description']['text'],
                        event['origin']['time']['value'],
                        event['origin']['latitude']['value'],
                        event['origin']['longitude']['value']])

# %%
dati_scelti[0]
# Out:
# ['33760891',
#  'Tirreno Meridionale (MARE)',
#  '2022-12-29T15:11:00.120000',
#  '39.3627',
#  '15.2153']

# %%
df = pd.DataFrame(dati_scelti,columns=['event_id','place','date','lat','lon'])
df
# Out:
#     event_id                                              place  \
# 0   33760891                         Tirreno Meridionale (MARE)
# 1   33759321                         Tirreno Meridionale (MARE)
# 2   33554561                              Isole Eolie (Messina)
# 3   33545491                            Bosnia and Herz. [Land]
# 4   33508291                            Bosnia and Herz. [Land]
# 5   33456501                                      Malta (MALTA)
# 6   33431491         Costa Marchigiana Pesarese (Pesaro-Urbino)
# 7   33332891              Costa Marchigiana Anconetana (Ancona)
# 8   33302041         Costa Marchigiana Pesarese (Pesaro-Urbino)
# 9   33301931              Costa Marchigiana Anconetana (Ancona)
# 10  33301831         Costa Marchigiana Pesarese (Pesaro-Urbino)
# 11  33239591             Golfo di Policastro (Salerno, Potenza)
# 12  33063421                              8 km E San Floro (CZ)
# 13  32828651                              2 km SW Bargagli (GE)
# 14  32791271               Costa Albanese meridionale (ALBANIA)
# 15  32506931           Confine Grecia-Albania (GRECIA, ALBANIA)
# 16  32478631                         3 km SW Caltabellotta (AG)
# 17  31720941                            Bosnia and Herz. [Land]
# 18  31431261           Costa Marchigiana Picena (Ascoli Piceno)
# 19  31385301            Costa Albanese settentrionale (ALBANIA)
# 20  30743631                            Bosnia and Herz. [Land]
# 21  30727451                            Bosnia and Herz. [Land]
# 22  30725281                            Bosnia and Herz. [Land]
# 23  30579191                       Mar Ionio Meridionale (MARE)
# 24  30341801                         Tirreno Meridionale (MARE)
# 25  30237631                    Northern Algeria [Sea: Algeria]
# 26  30129121  Costa Calabra sud-occidentale (Catanzaro, Vibo...
# 27  29890551                            Bosnia and Herz. [Land]
# 28  29883271                      5 km NE Bagnolo in Piano (RE)
# 29  29882731                       5 km E Bagnolo in Piano (RE)
# 30  29600121  Costa Calabra sud-occidentale (Catanzaro, Vibo...
#
#                           date      lat      lon
# 0   2022-12-29T15:11:00.120000  39.3627  15.2153
# 1   2022-12-29T12:38:53.300000  39.3663  15.2048
# 2   2022-12-04T07:12:45.370000   38.354   14.859
# 3   2022-12-02T20:05:06.870000  43.0918  18.1082
# 4   2022-11-28T07:49:50.077000   44.456  17.8333
# 5   2022-11-22T12:40:33.230000   36.034  14.1937
# 6   2022-11-20T05:20:30.250000  43.9027  13.2642
# 7   2022-11-10T17:54:12.160000  43.9155  13.3372
# 8   2022-11-09T06:12:57.730000  43.9662  13.3015
# 9   2022-11-09T06:08:28.990000  43.9133  13.3447
# 10  2022-11-09T06:07:25.000000  43.9833  13.3237
# 11  2022-10-31T21:42:48.960000  39.8747  15.6865
# 12  2022-10-12T22:44:55.000000    38.82   16.613
# 13  2022-09-22T13:39:59.360000  44.4328   9.0717
# 14  2022-09-18T13:54:40.190000  40.1581  19.8691
# 15  2022-08-23T13:38:33.000000    39.99    19.96
# 16  2022-08-21T04:52:49.260000  37.5625   13.194
# 17  2022-06-30T06:07:12.555000   43.476  17.5366
# 18  2022-06-09T11:18:00.140000  43.0493  14.0057
# 19  2022-06-06T04:16:27.440000  41.8138  19.2068
# 20  2022-04-24T04:27:55.390000  42.9617  18.0463
# 21  2022-04-23T02:20:27.640000  43.0365  18.0243
# 22  2022-04-22T21:07:49.680000  42.9522  18.0797
# 23  2022-04-15T01:34:40.830000  37.3138  15.6812
# 24  2022-03-29T01:48:14.940000  38.9772  14.0828
# 25  2022-03-19T09:59:33.401000  36.9211  5.10645
# 26  2022-03-04T21:17:52.530000  38.5947  15.6958
# 27  2022-02-10T14:17:55.150000  44.7182  18.5883
# 28  2022-02-09T20:00:57.000000  44.7862  10.7237
# 29  2022-02-09T18:55:12.780000  44.7803  10.7252
# 30  2022-01-20T09:19:57.010000  38.8307  16.0423
