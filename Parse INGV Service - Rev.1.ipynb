# %% [markdown]
# # Note
# * conviene **tralasciare eventi sotto 2+ magnitudine** perche **riduce il traffico sul server**
# * la risposta come **testo semplifica il parsing dei dati ricevuti**
# * conviene copiare i dati in un db diviso tra **dati storici (non cambiano) e dati recenti (ultimo giorno)** che puo cambiare molto spesso
# * il **db va partizionato** cosi i dati storici sono automaticamente inseriti nelle tabelle corrette **migliorando l'efficenza delle query**

# %% [markdown]
# # Call examples

# %% [raw]
# http://webservices.ingv.it/fdsnws/event/1/query?starttime=2022-01-01T00:00:00&endtime=2022-12-31T00:00:00&minmag=4.0&maxmag=9.0&minlatitude=35.0&maxlatitude=49.0&minlongitude=5.0&maxlongitude=20.0&limit=15000

# %% [raw]
# http://webservices.ingv.it/fdsnws/event/1/query?starttime=2023-07-01T00:00:00&endtime=2023-07-31T23:59:00&minmag=1.0&lat=41.76337&lon=12.33078&minradiuskm=1&maxradiuskm=200&format=xml

# %% [raw]
# http://webservices.ingv.it/fdsnws/event/1/query?starttime=2023-07-01T00:00:00&endtime=2023-07-30T12:00:00&minmag=2.0&minlat=36.71703&maxlat=46.99623&minlon=7.05809&maxlon=18.37819&format=text

# %% [raw]
# http://webservices.ingv.it/fdsnws/event/1/query?starttime=2023-07-01T00:00:00&endtime=2023-07-30T12:00:00&minmag=2.0&lat=41.76337&lon=12.33078&minradiuskm=1&maxradiuskm=200&format=text

# %% [markdown]
# # Pure XML

# %%
import xml.etree.ElementTree as ET
import pandas as pd
from urllib.request import urlopen

# %%
# FROM FILE
# tree = ET.parse("working_files/response_1688110777216.xml")

# %%
# REMOTE XML
rt = 'http://webservices.ingv.it/fdsnws/event/1/query?'
st = '2023-07-05T00:00:00'
ed = '2023-07-07T23:59:59'

# %% [markdown]
# ## Buffer Area

# %%
lat = 41.76337
lon = 12.33078
min_radius_km = 1
max_radius_km = 200

# %% [markdown]
# ## Bounding Box

# %%
lat = 41.76337
lon = 12.33078
min_radius_km = 1
max_radius_km = 200

# %% [markdown]
# # Processing response as "TEXT"

# %%
url_txt = f'{rt}starttime={st}&endtime={ed}&minmag=1.0&lat={lat}&lon={lon}&minradiuskm={min_radius_km}&maxradiuskm={max_radius_km}&format=text'

# %%
url_file_opened_txt=urlopen(url_txt)
events = url_file_opened_txt.readlines()
events
# Out:
# [b'#EventID|Time|Latitude|Longitude|Depth/Km|Author|Catalog|Contributor|ContributorID|MagType|Magnitude|MagAuthor|EventLocationName|EventType\n',
#  b'35487111|2023-07-06T11:12:12.830000|42.9005|13.5837|14.0|SURVEY-INGV||||ML|1.4|--|5 km N Ascoli Piceno (AP)|earthquake\n',
#  b'35486921|2023-07-06T10:31:44.870000|42.9203|13.6118|19.2|SURVEY-INGV||||ML|1.7|--|2 km SW Castignano (AP)|earthquake\n',
#  b'35481211|2023-07-05T17:55:24.370000|43.0653|13.0098|15.2|SURVEY-INGV||||ML|1.3|--|3 km SW Muccia (MC)|earthquake\n',
#  b'35480971|2023-07-05T17:39:25.600000|41.0987|10.3185|24.3|SURVEY-INGV||||ML|2.7|--|Tirreno Centrale (MARE)|earthquake\n',
#  b'35480551|2023-07-05T16:36:06.410000|42.6957|12.5722|8.5|SURVEY-INGV||||ML|1.3|--|2 km E Acquasparta (TR)|earthquake\n',
#  b'35480121|2023-07-05T15:55:56.130000|42.9813|13.2182|9.7|SURVEY-INGV||||ML|1.2|--|2 km SW Bolognola (MC)|earthquake\n',
#  b'35479771|2023-07-05T15:00:35.910000|43.3383|12.7787|12.8|SURVEY-INGV||||ML|1.0|--|3 km E Sigillo (PG)|earthquake\n',
#  b'35478911|2023-07-05T13:02:57.500000|41.9437|12.9358|8.3|SURVEY-INGV||||ML|1.4|--|2 km S Ciciliano (RM)|earthquake\n',
#  b'35478781|2023-07-05T12:39:03.790000|43.3373|13.2218|7.2|SURVEY-INGV||||ML|1.1|--|4 km S Cingoli (MC)|earthquake\n',
#  b'35478341|2023-07-05T12:08:03.830000|41.9522|12.9328|9.8|SURVEY-INGV||||ML|2.5|--|1 km SW Ciciliano (RM)|earthquake\n',
#  b'35475451|2023-07-05T07:16:02.310000|43.1147|13.0133|10.8|SURVEY-INGV||||ML|1.8|--|4 km NW Muccia (MC)|earthquake\n',
#  b'35475381|2023-07-05T07:13:15.360000|42.8453|13.0742|10.3|SURVEY-INGV||||ML|1.1|--|5 km SE Preci (PG)|earthquake\n',
#  b'35474971|2023-07-05T06:32:19.010000|43.0757|13.3287|23.4|SURVEY-INGV||||ML|1.1|--|1 km NW Gualdo (MC)|earthquake\n',
#  b'35474861|2023-07-05T06:00:10.670000|43.0673|13.0243|13.0|SURVEY-INGV||||ML|1.1|--|2 km SW Muccia (MC)|earthquake\n',
#  b'35472871|2023-07-05T02:50:37.240000|42.7308|13.0338|11.8|SURVEY-INGV||||ML|1.0|--|2 km NE Cascia (PG)|earthquake\n',
#  b'35472521|2023-07-05T00:29:00.950000|43.1323|11.0312|10.1|SURVEY-INGV||||ML|1.5|--|1 km E Montieri (GR)|earthquake\n',
#  b'35472411|2023-07-05T00:04:37.380000|42.9788|13.2162|9.0|SURVEY-INGV||||ML|1.4|--|2 km SW Bolognola (MC)|earthquake\n']

# %%
columns = events[0]
cols = [col for col in str(columns).lstrip("b'#").split("|")]
cols[-1]=cols[-1][:-3]

# %%
# cols

# %%
coded_events = []
for i in range(1,len(events)):
    event = str(events[i]).lstrip("b'").split("|")
    event[-1] = event[-1][:-3]    
    coded_events.append(event)

# %%
# coded_events

# %%
df = pd.DataFrame(coded_events, columns = cols)

# %%
df
# Out:
#      EventID                        Time Latitude Longitude Depth/Km  \
# 3   SURVEY-INGV                                        ML       1.2        --
# 4   SURVEY-INGV                                        ML       1.3        --
# 5   SURVEY-INGV                                        ML       2.2        --
# 6   SURVEY-INGV                                        ML       1.7        --
# 7   SURVEY-INGV                                        ML       1.4        --
# 8   SURVEY-INGV                                        ML       1.0        --
# 9   SURVEY-INGV                                        ML       1.2        --
# 10  SURVEY-INGV                                        ML       1.1        --
# 11  SURVEY-INGV                                        ML       1.4        --
# 12  SURVEY-INGV                                        ML       1.8        --
# 13  SURVEY-INGV                                        ML       1.6        --
# 14  SURVEY-INGV                                        ML       1.6        --
# 15  SURVEY-INGV                                        ML       1.0        --
# 16  SURVEY-INGV                                        ML       1.2        --
# 17  SURVEY-INGV                                        ML       1.2        --
# 18  SURVEY-INGV                                        ML       1.5        --
# 19  SURVEY-INGV                                        ML       2.2        --
# 20  SURVEY-INGV                                        ML       1.3        --
# 21  SURVEY-INGV                                        ML       2.7        --
# 22  SURVEY-INGV                                        ML       1.3        --
# 23  SURVEY-INGV                                        ML       1.2        --
# 24  SURVEY-INGV                                        ML       1.0        --
# 25  SURVEY-INGV                                        ML       1.4        --
# 26  SURVEY-INGV                                        ML       1.1        --
# 27  SURVEY-INGV                                        ML       2.5        --
# 28  SURVEY-INGV                                        ML       1.8        --
# 29  SURVEY-INGV                                        ML       1.1        --
# 30  SURVEY-INGV                                        ML       1.1        --
# 31  SURVEY-INGV                                        ML       1.1        --
# 32  SURVEY-INGV                                        ML       1.0        --
# 33  SURVEY-INGV                                        ML       1.5        --
# 34  SURVEY-INGV                                        ML       1.4        --
#
#                    EventLocationName   EventType
# 0          5 km N Ascoli Piceno (AP)  earthquake
# 1            2 km SW Castignano (AP)  earthquake
# 2           5 km SW Acquacanina (MC)  earthquake
# 3          4 km N Ascoli Piceno (AP)  earthquake
# 4             2 km SW Bolognola (MC)  earthquake
# 5          4 km N Ascoli Piceno (AP)  earthquake
# 6               1 km E Falerone (FM)  earthquake
# 7            3 km E Pietralunga (PG)  earthquake
# 8               2 km E Accumoli (RI)  earthquake
# 9            5 km SW Castignano (AP)  earthquake
# 10      1 km SE Pievebovigliana (MC)  earthquake
# 11          3 km SE Pietralunga (PG)  earthquake
# 12  1 km SW Castel San Vincenzo (IS)  earthquake
# 13              3 km W Leonessa (RI)  earthquake
# 14             1 km W Ciciliano (RM)  earthquake
# 15        4 km NW Monte Cavallo (MC)  earthquake
# 16            3 km SW Ciciliano (RM)  earthquake
# 17        2 km SW Monte Cavallo (MC)  earthquake
# 18             2 km W Ciciliano (RM)  earthquake
# 19            2 km SW Ciciliano (RM)  earthquake
# 20               3 km SW Muccia (MC)  earthquake
# 21           Tirreno Centrale (MARE)  earthquake
# 22           2 km E Acquasparta (TR)  earthquake
# 23            2 km SW Bolognola (MC)  earthquake
# 24               3 km E Sigillo (PG)  earthquake
# 25             2 km S Ciciliano (RM)  earthquake
# 26               4 km S Cingoli (MC)  earthquake
# 27            1 km SW Ciciliano (RM)  earthquake
# 28               4 km NW Muccia (MC)  earthquake
# 29                5 km SE Preci (PG)  earthquake
# 30               1 km NW Gualdo (MC)  earthquake
# 31               2 km SW Muccia (MC)  earthquake
# 32               2 km NE Cascia (PG)  earthquake
# 33              1 km E Montieri (GR)  earthquake
# 34            2 km SW Bolognola (MC)  earthquake

# %% [markdown]
# # Processing response as "QUAKEML"

# %%
url_xml = f'{rt}starttime={st}&endtime={ed}&minmag=1.0&lat={lat}&lon={lon}&minradiuskm={min_radius_km}&maxradiuskm={max_radius_km}'
url_file_opened_xml=urlopen(url_xml)
tree = ET.parse(url_file_opened_xml)

# %%
root = tree.getroot()

# %%
root.tag
# Out:
# '{http://quakeml.org/xmlns/quakeml/1.2}quakeml'

# %%
root.attrib
# Out:
# {}

# %% [markdown]
# # ALL ATTRIBS

# %%
# [elem.tag for elem in root.iter()]
# Out:
# ['{http://quakeml.org/xmlns/quakeml/1.2}quakeml',
#  '{http://quakeml.org/xmlns/bed/1.2}eventParameters',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}id_locator',
#  '{http://quakeml.org/xmlns/bed/1.2}origin',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationMode',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}time',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}latitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}longitude',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depth',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}depthType',
#  '{http://quakeml.org/xmlns/bed/1.2}originUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredDescription',
#  '{http://quakeml.org/xmlns/bed/1.2}horizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}minHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}maxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthMaxHorizontalUncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}confidenceLevel',
#  '{http://quakeml.org/xmlns/bed/1.2}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}azimuthalGap',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedPhaseCount',
#  '{http://quakeml.org/xmlns/bed/1.2}standardError',
#  '{http://quakeml.org/xmlns/bed/1.2}minimumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}maximumDistance',
#  '{http://quakeml.org/xmlns/bed/1.2}associatedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}usedStationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}evaluationStatus',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}earthModelID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}version',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}quality',
#  '{http://quakeml.org/xmlns/bed/1.2}magnitude',
#  '{http://quakeml.org/xmlns/bed/1.2}stationCount',
#  '{http://quakeml.org/xmlns/bed/1.2}originID',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}mag',
#  '{http://quakeml.org/xmlns/bed/1.2}value',
#  '{http://quakeml.org/xmlns/bed/1.2}uncertainty',
#  '{http://quakeml.org/xmlns/bed/1.2}methodID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  '{http://quakeml.org/xmlns/bed/1.2}agencyID',
#  '{http://quakeml.org/xmlns/bed/1.2}author',
#  '{http://quakeml.org/xmlns/bed/1.2}creationTime',
#  '{http://webservices.ingv.it/fdsnws/event/1}mag_quality',
#  '{http://quakeml.org/xmlns/bed/1.2}event',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}description',
#  '{http://quakeml.org/xmlns/bed/1.2}type',
#  '{http://quakeml.org/xmlns/bed/1.2}text',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredMagnitudeID',
#  '{http://quakeml.org/xmlns/bed/1.2}preferredOriginID',
#  '{http://quakeml.org/xmlns/bed/1.2}creationInfo',
#  ...]

# %% [markdown]
# # Filtering

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# {http://quakeml.org/xmlns/bed/1.2}eventParameters {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query'}

# %%
for quake in root.iter('{http://quakeml.org/xmlns/bed/1.2}eventParameters'):
    print(quake.tag)
    print(quake.attrib)
# Out:
# {http://quakeml.org/xmlns/bed/1.2}eventParameters
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query'}

# %%
for quake in root.iter('{http://quakeml.org/xmlns/bed/1.2}event'):
    # print(quake.tag)
    print(quake.attrib)
# Out:
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35487111'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35486921'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485771'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485671'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485591'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485291'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35484871'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35484261'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35484081'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483971'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483621'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483401'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483351'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482741'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482611'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482411'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482351'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482231'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35481621'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35481441'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35481211'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35480971'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35480551'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35480121'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35479771'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35478911'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35478781'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35478341'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35475451'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35475381'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35474971'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35474861'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35472871'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35472521'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35472411'}

# %%
# for quake in root.iter('{http://quakeml.org/xmlns/bed/1.2}origin'):
#     print(quake.attrib)
# Out:
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119019041'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119017651'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119014001'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119013861'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119013831'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119012611'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119010151'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119009471'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119009031'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119008151'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119007691'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119006921'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119006091'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119002641'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119002001'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119000901'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119000871'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=119000511'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118999551'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118999221'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118998321'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118998421'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118997111'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118996491'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118995861'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118992871'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118991741'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118990841'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118984021'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118984151'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118982991'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118982601'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118977411'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118975541'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?originId=118975351'}

# %%
# for quake in root.iter('{http://quakeml.org/xmlns/bed/1.2}creationTime'):
#     print(quake.text)

# %%
# for quake in root.iter('{http://quakeml.org/xmlns/bed/1.2}author'):
#     print(quake.text)

# %%
root[0].attrib
# Out:
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query'}

# %%
root[0].tag
# Out:
# '{http://quakeml.org/xmlns/bed/1.2}eventParameters'

# %%
root[0].text
# Out:
# '\n    '

# %%
root[0][0][1][1].text
# Out:
# '5 km N Ascoli Piceno (AP)'

# %% [markdown]
# # Data for Single Event

# %%
for quake in root.iter('{http://quakeml.org/xmlns/bed/1.2}event'):
    print(quake.attrib)
# Out:
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35487111'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35486921'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485771'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485671'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485591'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35485291'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35484871'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35484261'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35484081'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483971'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483621'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483401'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35483351'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482741'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482611'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482411'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482351'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35482231'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35481621'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35481441'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35481211'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35480971'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35480551'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35480121'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35479771'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35478911'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35478781'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35478341'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35475451'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35475381'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35474971'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35474861'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35472871'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35472521'}
# {'publicID': 'smi:webservices.ingv.it/fdsnws/event/1/query?eventId=35472411'}

# %%
event_id = 35486921

# %%
url_single_event = f'{rt}eventId={event_id}&includeallmagnitudes=true&includeallorigins=true&lat={lat}&includearrivals=true&includeallstationsmagnitudes=true'
url_single_event
# Out:
# 'http://webservices.ingv.it/fdsnws/event/1/query?eventId=35486921&includeallmagnitudes=true&includeallorigins=true&lat=41.76337&includearrivals=true&includeallstationsmagnitudes=true'

# %%
url_file_opened_xml_single_event=urlopen(url_single_event)
tree_se = ET.parse(url_file_opened_xml_single_event)
root_se = tree_se.getroot()

# %%
root_se[0][0][1][1].text
# Out:
# '2 km SW Castignano (AP)'
